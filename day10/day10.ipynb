# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\cngan\\Downloads\\customer_orders.csv")

# %%
print("Shape before cleaning:", df.shape)
# Out:
# Shape before cleaning: (11, 4)

# %%
print("\nMissing values report:")
print(df.isna().sum())
# Out:
# Missing values report:
# order_id       2
# customer_id    0
# amount         2
# quantity       2
# dtype: int64

# %%
numeric_columns = df.select_dtypes(include=['number']).columns

for col in numeric_columns:
    df[col] = df[col].fillna(df[col].median())

# %%
df = df.drop_duplicates()
print("\nShape after cleaning:", df.shape)
# Out:
# Shape after cleaning: (9, 4)

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\cngan\\Downloads\\sales_data.csv")

# %%
print("Initial Data Types:\n")
print(df.dtypes)
# Out:
# Initial Data Types:
#
# Product    object
# Price      object
# Date       object
# dtype: object

# %%
df["Price"] = df["Price"].str.replace("$", "", regex=False).astype(float)

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
print("\nData Types After Conversion:\n")
print(df.dtypes)
# Out:
# Data Types After Conversion:
#
# Product            object
# Price             float64
# Date       datetime64[ns]
# dtype: object

# %%
print("\nAverage Price:", df["Price"].mean())
print("\nSorted by Date:\n")
print(df.sort_values("Date"))
# Out:
# Average Price: 475.16333333333324
#
# Sorted by Date:
#
#     Product    Price       Date
# 0    Laptop   750.50 2026-01-10
# 1     Phone  1200.00 2026-01-12
# 2    Tablet   450.99 2026-01-15
# 3   Monitor   300.00 2026-01-18
# 4  Keyboard    99.99 2026-02-01
# 5     Mouse    49.50 2026-02-05

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\cngan\\Downloads\\location_data.csv")

# %%
print("Unique values BEFORE cleaning:")
print(df["Location"].unique())
# Out:
# Unique values BEFORE cleaning:
# [' New York' 'new york' 'NEW YORK ' 'Los Angeles' ' los angeles '
#  'LOS ANGELES']

# %%
df["Location"] = df["Location"].str.strip()

# %%
df["Location"] = df["Location"].str.title()

# %%
print("\nUnique values AFTER cleaning:")
print(df["Location"].unique())
# Out:
# Unique values AFTER cleaning:
# ['New York' 'Los Angeles']
